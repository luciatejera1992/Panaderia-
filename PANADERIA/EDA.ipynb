# %%
#%pip install pandas numpy seaborn matplotlib
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np
import seaborn as sbn
import matplotlib  as plt

# %%
dfprice = pd.read_csv(r"data/Bakeryprice.csv")
dfprice.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    22 non-null     str
#  1   price   22 non-null     str
# dtypes: str(2)
# memory usage: 484.0 bytes

# %%
dfsales = pd.read_csv("data/Bakerysales.csv")

# %%
dfsales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2654 entries, 0 to 2653
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            2421 non-null   str
#  1   day of week         2420 non-null   str
#  2   total               2420 non-null   float64
#  3   place               2166 non-null   str
#  4   angbutter           1973 non-null   float64
#  5   plain bread         857 non-null    float64
#  6   jam                 220 non-null    float64
#  7   americano           412 non-null    float64
#  8   croissant           747 non-null    float64
#  9   caffe latte         193 non-null    float64
#  10  tiramisu croissant  779 non-null    float64
#  11  cacao deep          323 non-null    float64
#  12  pain au chocolat    587 non-null    float64
#  13  almond croissant    202 non-null    float64
#  14  croque monsieur     0 non-null      float64
# ...

# %%
dfsales.describe()
# Out:
#               total    angbutter  plain bread         jam   americano  \
# count  2.420000e+03  1973.000000   857.000000  220.000000  412.000000
# mean   2.117252e+04     1.636594     1.199533    1.131818    1.245146
# std    2.699727e+04     1.115636     0.510268    0.433617    0.527216
# min    1.280000e+04     1.000000     1.000000    1.000000    1.000000
# 25%    1.580000e+04     1.000000     1.000000    1.000000    1.000000
# 50%    1.850000e+04     1.000000     1.000000    1.000000    1.000000
# 75%    2.300000e+04     2.000000     1.000000    1.000000    1.000000
# max    1.293000e+06    11.000000     5.000000    5.000000    5.000000
#
#         croissant  caffe latte  tiramisu croissant  cacao deep  \
# count  747.000000   193.000000          779.000000  323.000000
# mean     1.404284     1.108808            1.213094    1.126935
# std      1.027704     0.373016            0.797350    0.393249
# min      1.000000     1.000000            1.000000    1.000000
# ...

# %%
dfsales.count()
# Out:
# datetime              2421
# day of week           2420
# total                 2420
# place                 2166
# angbutter             1973
# plain bread            857
# jam                    220
# americano              412
# croissant              747
# caffe latte            193
# tiramisu croissant     779
# cacao deep             323
# pain au chocolat       587
# almond croissant       202
# croque monsieur          0
# mad garlic               0
# milk tea               137
# gateau chocolat        196
# pandoro                343
# cheese cake             90
# lemon ade               35
# orange pound           519
# wiener                 355
# vanila latte           209
# berry ade               54
# tiramisu                 7
# merinque cookies        47
# dtype: int64

# %%
dfsales.nunique()
# Out:
# datetime              2361
# day of week              7
# total                  257
# place                   19
# angbutter               11
# plain bread              5
# jam                      4
# americano                5
# croissant                7
# caffe latte              3
# tiramisu croissant       9
# cacao deep               4
# pain au chocolat         6
# almond croissant         4
# croque monsieur          0
# mad garlic               0
# milk tea                 4
# gateau chocolat          2
# pandoro                  5
# cheese cake              2
# lemon ade                3
# orange pound             3
# wiener                   5
# vanila latte             4
# berry ade                2
# tiramisu                 1
# merinque cookies         2
# dtype: int64

# %%
dfsales.isnull().sum()
# Out:
# datetime               233
# day of week            234
# total                  234
# place                  488
# angbutter              681
# plain bread           1797
# jam                   2434
# americano             2242
# croissant             1907
# caffe latte           2461
# tiramisu croissant    1875
# cacao deep            2331
# pain au chocolat      2067
# almond croissant      2452
# croque monsieur       2654
# mad garlic            2654
# milk tea              2517
# gateau chocolat       2458
# pandoro               2311
# cheese cake           2564
# lemon ade             2619
# orange pound          2135
# wiener                2299
# vanila latte          2445
# berry ade             2600
# tiramisu              2647
# merinque cookies      2607
# dtype: int64

# %%
dfsales.duplicated().sum()
# Out:
# np.int64(232)

# %%
# analizar dataset para saber si hay datos faltantes, duplicados o inconsistentes. Esto es importante para garantizar la calidad de los datos antes de realizar cualquier análisis o modelado.

dfprice.isnull().sum()
dfprice.duplicated().sum()
# Out:
# np.int64(0)

# %%
dfsales.duplicated().sum()
# Out:
# np.int64(232)

# %%
dfsales.isnull().sum()
# Out:
# datetime               233
# day of week            234
# total                  234
# place                  488
# angbutter              681
# plain bread           1797
# jam                   2434
# americano             2242
# croissant             1907
# caffe latte           2461
# tiramisu croissant    1875
# cacao deep            2331
# pain au chocolat      2067
# almond croissant      2452
# croque monsieur       2654
# mad garlic            2654
# milk tea              2517
# gateau chocolat       2458
# pandoro               2311
# cheese cake           2564
# lemon ade             2619
# orange pound          2135
# wiener                2299
# vanila latte          2445
# berry ade             2600
# tiramisu              2647
# merinque cookies      2607
# dtype: int64
